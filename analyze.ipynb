# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('combustion.csv',index_col=0)

# %%
df.head()
# Out:
#      Pc       eps    MR        Cstar    PcOvPe  subar           Tc  \
# 0  17.0  1.000879  0.75  1098.809268  1.678184      3  1085.460377
# 1  17.0  1.000879  0.75  1098.809268  1.678184      2  1085.460377
# 2  17.0  1.001026  1.00  1139.399724  1.678184      3  1140.034568
# 3  17.0  1.001026  1.00  1139.399724  1.678184      2  1140.034568
# 4  17.0  1.001190  1.25  1169.981222  1.678184      3  1197.565234
#
#             Tt           Te         Isp     gamma
# 0  1030.853078  1027.691435  138.243787  1.136492
# 1  1030.853078  1027.691435  138.243787  1.136492
# 2  1079.768411  1076.053771  143.508297  1.144131
# 3  1079.768411  1076.053771  143.508297  1.144131
# 4  1122.574428  1118.111379  147.739013  1.155159

# %%
df.sort_values('Isp',ascending=False)
# Out:
#         Pc       eps    MR        Cstar    PcOvPe  subar           Tc  \
# 2643  39.5  1.315677  4.75  1588.150553  3.899309      2  3184.096334
# 2642  39.5  1.315677  4.75  1588.150553  3.899309      3  3184.096334
# 2641  39.5  1.308070  4.50  1588.940675  3.899309      2  3164.039868
# 2640  39.5  1.308070  4.50  1588.940675  3.899309      3  3164.039868
# 2645  39.5  1.320961  5.00  1584.930164  3.899309      2  3194.684539
# ...    ...       ...   ...          ...       ...    ...          ...
# 116   18.0  1.000511  0.75  1099.616482  1.776900      3  1088.858906
# 1     17.0  1.000879  0.75  1098.809268  1.678184      2  1085.460377
# 0     17.0  1.000879  0.75  1098.809268  1.678184      3  1085.460377
# 59    17.5  1.000007  0.75  1099.218747  1.727542      2  1087.181918
# 58    17.5  1.000007  0.75  1099.218747  1.727542      3  1087.181918
#
#                Tt           Te         Isp     gamma
# 2643  2992.064520  2714.649617  217.909961  1.164867
# ...
