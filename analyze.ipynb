# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('combustion.csv',index_col=0)

# %%
df.head()
# Out:
#      fuel   Pc  eps    MR    PcOvPe  subar          Tc          Tt  \
# 0  C2H5OH  5.0  NaN  0.75  0.493583    1.0  1016.60809  968.423233
# 1  C2H5OH  5.0  NaN  0.75  0.493583    1.5  1016.60809  968.423233
# 2  C2H5OH  5.0  NaN  0.75  0.493583    2.0  1016.60809  968.423233
# 3  C2H5OH  5.0  NaN  0.75  0.493583    2.5  1016.60809  968.423233
# 4  C2H5OH  5.0  NaN  0.75  0.493583    3.0  1016.60809  968.423233
#
#            Te  Isp  gamma
# 0  1085.70914  0.0    0.0
# 1  1085.70914  0.0    0.0
# 2  1085.70914  0.0    0.0
# 3  1085.70914  0.0    0.0
# 4  1085.70914  0.0    0.0

# %%
df = df.dropna()

# %%
df.sort_values('Isp',ascending=False)
# Out:
#           fuel    Pc       eps    MR    PcOvPe  subar           Tc  \
# 42751  methane  10.5  2.469921  7.25  1.036525    1.5  3164.004217
# 42759  methane  10.5  2.469921  7.25  1.036525    5.5  3164.004217
# 42753  methane  10.5  2.469921  7.25  1.036525    2.5  3164.004217
# 42754  methane  10.5  2.469921  7.25  1.036525    3.0  3164.004217
# 42755  methane  10.5  2.469921  7.25  1.036525    3.5  3164.004217
# ...        ...   ...       ...   ...       ...    ...          ...
# 13054   C2H5OH  17.5  1.000007  0.75  1.727542    3.0  1087.181918
# 13053   C2H5OH  17.5  1.000007  0.75  1.727542    2.5  1087.181918
# 13052   C2H5OH  17.5  1.000007  0.75  1.727542    2.0  1087.181918
# 13051   C2H5OH  17.5  1.000007  0.75  1.727542    1.5  1087.181918
# 13067   C2H5OH  17.5  1.000007  0.75  1.727542    9.5  1087.181918
#
#                 Tt           Te         Isp     gamma
# 42751  2961.225424  2231.812708  259.053503  1.226995
# ...
